# %% [markdown]
# # World energy Data Analysis
# In this project I am going to perform some data analysis on a dataset containing information about energy production in the whole world, from 1990 up until 2020.
# The dataset can be found at the following link on Kaggle https://www.kaggle.com/datasets/shub218/energy-data-1990-2020.
#
# First let us import the necessary libraries:

# %%
import pandas as pd

# %% [markdown]
# The next step is going to be importing the data and starting to analyze it:

# %%
df=pd.read_csv('Energy data 1990 - 2020 2.csv')

# %%
df
# Out:
#         country  Year               Region  \
# 0       Algeria  1990          Arab States
# 1       Algeria  1991          Arab States
# 2       Algeria  1992          Arab States
# 3       Algeria  1993          Arab States
# 4       Algeria  1994          Arab States
# ...         ...   ...                  ...
# 1359  Venezuela  2016  South/Latin America
# 1360  Venezuela  2017  South/Latin America
# 1361  Venezuela  2018  South/Latin America
# 1362  Venezuela  2019  South/Latin America
# 1363  Venezuela  2020  South/Latin America
#
#       CO2 emissions from fuel combustion (MtCO2)  \
# 0                                      52.981921
# 1                                      57.149971
# 2                                      57.262430
# 3                                      59.198702
# 4                                      56.347927
# ...                                          ...
# 1359                                  130.244135
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         country  Year               Region  \
# 0       Algeria  1990          Arab States
# 1       Algeria  1991          Arab States
# 2       Algeria  1992          Arab States
# 3       Algeria  1993          Arab States
# 4       Algeria  1994          Arab States
# ...         ...   ...                  ...
# 1359  Venezuela  2016  South/Latin America
# 1360  Venezuela  2017  South/Latin America
# 1361  Venezuela  2018  South/Latin America
# 1362  Venezuela  2019  South/Latin America
# 1363  Venezuela  2020  South/Latin America
#
#       CO2 emissions from fuel combustion (MtCO2)  \
# 0                                      52.981921
# 1                                      57.149971
# 2                                      57.262430
# 3                                      59.198702
# 4                                      56.347927
# ...                                          ...
# 1359                                  130.244135
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         country  Year               Region  \
# 0       Algeria  1990          Arab States
# 1       Algeria  1991          Arab States
# 2       Algeria  1992          Arab States
# 3       Algeria  1993          Arab States
# 4       Algeria  1994          Arab States
# ...         ...   ...                  ...
# 1359  Venezuela  2016  South/Latin America
# 1360  Venezuela  2017  South/Latin America
# 1361  Venezuela  2018  South/Latin America
# 1362  Venezuela  2019  South/Latin America
# 1363  Venezuela  2020  South/Latin America
#
#       CO2 emissions from fuel combustion (MtCO2)  \
# 0                                      52.981921
# 1                                      57.149971
# 2                                      57.262430
# 3                                      59.198702
# 4                                      56.347927
# ...                                          ...
# 1359                                  130.244135
# ...
